# %%
import numpy as np 
from scipy.ndimage.interpolation import zoom, map_coordinates
import torch
import matplotlib.pyplot as plt
from torchvision.utils import make_grid
# %matplotlib inline

# %%
# def rgb2gray(rgb):
# #     r, g, b = rgb[:,:,0], rgb[:,:,1], rgb[:,:,2]
# #     gray = 0.2989 * r + 0.5870 * g + 0.1140 * b
# #     return gray
# # def show(img):
# #     npimg = img.numpy()
# #     plt.imshow(np.transpose(npimg, (1,2,0)), interpolation='nearest')
# # img = plt.imread('Q9jiI1pL_400x400.jpg')
#def generate_grid(shape):
# if len(shape) == 2:
# #         x = torch.range(0, shape[0]-1)
# #         y = torch.range(0, shape[1]-1)
# #         grid = torch.stack([x.repeat(shape[1]), y.repeat(shape[0],1).t().contiguous().view(-1)],1)
# #     elif len(shape) == 3:
# #         x = torch.range(0, shape[0]-1)
# #         y = torch.range(0, shape[1]-1)
# #         z = torch.range(0, shape[2]-1)
# #     return grid

# %%
vector_fields = torch.from_numpy(np.random.normal(size=(2,5,5)))
resolution=2
order='nearest'
shape = (5,5)
ratio = tuple([int(ax/resolution) for ax in shape])
data = torch.nn.functional.upsample(vector_fields, scale_factor=resolution, mode=order)
# Out:
# /nmnt/media/home/ayagoz/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")

# %%
plt.imshow(data.numpy())
# Out:
# ----------------------------------------------------------------------
# TypeError                            Traceback (most recent call last)
# <ipython-input-108-e2b2b80c605d> in <module>()
# ----> 1 plt.imshow(data.numpy())
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3099                         filternorm=filternorm, filterrad=filterrad,
#    3100                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3101                         **kwargs)
#    3102     finally:
#    3103         ax._hold = washold
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5129                               resample=resample, **kwargs)
#    5130
# -> 5131         im.set_data(X)
#    5132         im.set_alpha(alpha)
#    5133         if im.get_clip_path() is None:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/image.py in set_data(self, A)
#     620         if not (self._A.ndim == 2
#     621                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
# --> 622             raise TypeError("Invalid dimensions for image data")
#     623
#     624         self._imcache = None
#
# TypeError: Invalid dimensions for image data

# %% [markdown]
# torch einsum ??!!

# %%
shape = (2,5,5)
J = np.random.normal(size=shape)
vector_fields = np.random.uniform(size=(5,) + shape)

# %%
np_ein = np.einsum('ij...,j...->i...', J, vector_fields)

# %%
np_ein.shape
# Out:
# (2, 2, 5, 5)

# %%
torch_ein = torch.einsum('ij...,j...->i...',
                                [torch.from_numpy(J),
                                torch.from_numpy(vector_fields)])
# Out:
# ----------------------------------------------------------------------
# RuntimeError                         Traceback (most recent call last)
# <ipython-input-93-9a0849a669ae> in <module>()
#       1 torch_ein = torch.einsum('ij...,j...->i...',
#       2                                 [torch.from_numpy(J),
# ----> 3                                 torch.from_numpy(vector_fields)])
#
# RuntimeError: ellipsis must represent 1 dimensions in all terms

# %%
a = torch.rand(32, 48, 9, 3)
print(np.einsum('...ji,...jk->...ik', a, a).shape)
# (32, 48, 3, 3)

print(torch.einsum('...ji,...jk->...ik', [a, a]).shape)
# Out:
# (32, 48, 3, 3)
# torch.Size([32, 48, 3, 3])

# %% [markdown]
# Create grid in pytorch

# %%
shape = (5,5)
grid = identity_mapping(shape)

# %%
grid.clone().type(torch.float)
# Out:
# tensor([[[0., 0., 0.],
#          [1., 1., 1.],
#          [2., 2., 2.]],
#
#         [[0., 1., 2.],
#          [0., 1., 2.],
#          [0., 1., 2.]]])

# %% [markdown]
# Test det in pytorch

# %%
N=10*5
A = np.random.normal(size=(N,N)) + 100*np.eye(N)
A_t = torch.from_numpy(A)

# %%
# %%timeit
torch.from_numpy(A)
# Out:
# 1.09 µs ± 48.1 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %%timeit
np.linalg.det(A)
# Out:
# 31.5 µs ± 362 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %%timeit
torch.eig(A_t)
# Out:
# 550 µs ± 6.39 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit
torch.potrf(A_t).diag().prod()
# Out:
# 15.9 µs ± 99.7 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %%timeit
torch.det(A_t)
# Out:
# 42.3 µs ± 575 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# Test det in tensor version for 2D

# %%
N = 10**3
dim = 2
size = (dim,)*2 +  (N,)*2
J = np.random.normal(size=size)
J_t = torch.from_numpy(J)

# %%
# %%timeit
det2D = J[0, 0] * J[1, 1] - J[0, 1] * J[1, 0]
# Out:
# 4.09 ms ± 28.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
det2D_t = J_t[0, 0] * J_t[1, 1] - J_t[0, 1] * J_t[1, 0]
# Out:
# 2.55 ms ± 13.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# Test det in tensor version for 3D

# %%
N = 10**2
dim = 3
size = (dim,)*2 +  (N,)*3
J = np.random.normal(size=size)
J_t = torch.from_numpy(J)

# %%
# %%timeit
det3D = (J[0, 0] * J[1, 1] * J[2, 2]
                + J[1, 0] * J[2, 1] * J[0, 2]
                + J[0, 1] * J[1, 2] * J[2, 0]
                - J[0, 0] * J[1, 2] * J[2, 1]
                - J[2, 2] * J[1, 0] * J[0, 1]
                - J[0, 2] * J[1, 1] * J[2, 0])
# Out:
# 20.5 ms ± 143 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
det3D_t = (J_t[0, 0] * J_t[1, 1] * J_t[2, 2]
                + J_t[1, 0] * J_t[2, 1] * J_t[0, 2]
                + J_t[0, 1] * J_t[1, 2] * J_t[2, 0]
                - J_t[0, 0] * J_t[1, 2] * J_t[2, 1]
                - J_t[2, 2] * J_t[1, 0] * J_t[0, 1]
                - J_t[0, 2] * J_t[1, 1] * J_t[2, 0])
# Out:
# 14.4 ms ± 65.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# Test upsampling| grid_sample| zoom

# %%
def identity_mapping(shape):
    return np.mgrid[tuple(map(slice, shape))]

# %%
def bilinear_grid_sample(image, grid_x, grid_y):
    image = image.permute(0,1)  
    if len(image.shape) == 2:
        image = image.unsqueeze(0).unsqueeze(0)
    W, H = image.shape[2:]
    
    samples_x = grid_y.unsqueeze(0)
    samples_y = grid_x.unsqueeze(0)

    samples_x = samples_x.unsqueeze(3)
    samples_y = samples_y.unsqueeze(3)
    samples = torch.cat([samples_x, samples_y],3)
    samples[:,:,:,0] = samples[:,:,:,0]/(W-1) # normalize to between  0 and 1
    samples[:,:,:,1] = samples[:,:,:,1]/(H-1) # normalize to between  0 and 1
    samples = samples*2-1  
    
    return torch.nn.functional.grid_sample(image, samples).squeeze(0).squeeze(0)

# %%
def rgb2gray(rgb):
    r, g, b = rgb[:,:,0], rgb[:,:,1], rgb[:,:,2]
    gray = 0.2989 * r + 0.5870 * g + 0.1140 * b
    return gray

# %%
a = np.array([[0,1,1,1],[1,0,1,0],[0,0,1,1], [0,0,1,1]]).astype(float)

# %%
o = 1
axis_zoom = (0.5,0.5)
a_zoom = zoom(a, axis_zoom, order=o)
a_zoom
# Out:
# array([[0., 1.],
#        [0., 1.]])

# %%
a_t = torch.from_numpy(a)
# a_t = a_t.unsqueeze(0)
print(a_t.shape)
axis =  axis_zoom
# Out:
# torch.Size([4, 4])

# %%
new_size = torch.Size([int(a_t.shape[i]*axis[i]) for i in range(a_t.dim())])

# %%
new_size
# Out:
# torch.Size([2, 2])

# %%
a_upsample = torch.nn.functional.upsample(a_t.unsqueeze(0).unsqueeze(0), size=new_size)

#interpolate(a_t, size=tuple(np.array(new_size).astype(int)), mode='linear')
# Out:
# /nmnt/media/home/ayagoz/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")

# %%
a_upsample
# Out:
# tensor([[[[0., 1.],
#           [0., 1.]]]], dtype=torch.float64)

# %%
shape = a.shape
grid = identity_mapping(shape)
zoomed_grid = grid[np.ix_([0,1],range(0,shape[0],2),range(0,shape[1], 2))]

# %%
image = torch.FloatTensor(a).cuda()
sample_x = torch.FloatTensor(zoomed_grid[0]).cuda()#.unsqueeze(0)
sample_y = torch.FloatTensor(zoomed_grid[1]).cuda()
vf_image = bilinear_grid_sample(image, sample_x, sample_y)

# %%
vf_image
# Out:
# tensor([[0., 1.],
#         [0., 1.]], device='cuda:0')

# %%
img = rgb2gray(plt.imread('Q9jiI1pL_400x400.jpg', ))

# %%
plt.imshow(img);

# %%
o = 1
axis = (10.,10.)
print(axis)
zoom_img = zoom(img, axis, order=o)
# Out:
# (10.0, 10.0)

# %%
plt.imshow(zoom_img);

# %%
k = 10
img_t = torch.from_numpy(img) 
new_size = new_size = torch.Size([int(img_t.shape[i]*10) for i in range(img_t.dim())])
img_upsample = torch.nn.functional.upsample(img_t.unsqueeze(0).unsqueeze(0), size=new_size, mode='bilinear')
#interpolate(a_t, size=tuple(np.array(new_size).astype(int)), mode='linear')
# Out:
# /nmnt/media/home/ayagoz/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /nmnt/media/home/ayagoz/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1961: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))

# %%
img_upsample = img_upsample.squeeze(0).squeeze(0)
plt.imshow(img_upsample);

# %%
plt.imshow(zoom_img - img_upsample);

# %%
k = 10.
grid = identity_mapping((img.shape[0]*k, img.shape[1]*k))
zoomed_grid = grid/k

# %%
image = torch.FloatTensor(img).cuda()
sample_x = torch.FloatTensor(zoomed_grid[0]).cuda()#.unsqueeze(0)
sample_y = torch.FloatTensor(zoomed_grid[1]).cuda()
vf_image = bilinear_grid_sample(image, sample_x, sample_y)

# %%
plt.imshow(vf_image.cpu().numpy());

# %%
plt.imshow(zoom_img - vf_image.cpu().numpy());
plt.colorbar();

# %%
img.max(), img.min()
# Out:
# (254.97449999999998, 56.803799999999995)
